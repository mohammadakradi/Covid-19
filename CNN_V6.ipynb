# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammad2682/Covid-19/blob/master/CNN_V6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cloning Dataset from GitHub Reporsitory

# %%
# !git clone https://github.com/mohammad2682/Covid19-Dataset
# Out:
# Cloning into 'Covid19-Dataset'...
# remote: Enumerating objects: 3253, done.
# remote: Total 3253 (delta 0), reused 0 (delta 0), pack-reused 3253
# Receiving objects: 100% (3253/3253), 315.60 MiB | 14.43 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Checking out files: 100% (5710/5710), done.

# %% [markdown]
# ## Importing Liberaries

# %%
import numpy as np 
import pandas as pd
import cv2
import os
from matplotlib import pyplot as plt
import keras

# %%
from keras.models import Model
from keras.layers import Conv2D, Input
from keras.layers import MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import BatchNormalization, Dropout, Activation
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Reading Dataset

# %%
disease_types=['COVID', 'non-COVID']
data_dir = 'Covid19-Dataset/Covid-19-Dataset/train'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
IMAGE_SIZE = 128
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
from tqdm import tqdm
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2000it [00:07, 266.93it/s]
# Train Shape: (2000, 128, 128, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

SEED=42
# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %% [markdown]
# ## Creating a 3layered CNN

# %%
# Initialising the CNN
# Step 1 - Convolution
# First Layer
input_img = Input(shape=(128, 128, 3))
x = Conv2D(3, (7,7), activation='relu')(input_img)
x = Dropout(0.3)(x)
x = MaxPooling2D(pool_size=(2,2))(x)
# Second Layer
x = Conv2D(64, (7,7), activation='relu')(x)
x = Dropout(0.3)(x)
x = MaxPooling2D(pool_size=(2,2))(x)
# Third Layer
x = Conv2D(128, (7, 7), activation = 'relu')(x)
x = Dropout(0.3)(x)
x = MaxPooling2D(pool_size=(2,2))(x)
#Inception Layer
layer_1 = Conv2D(10, (1,1), padding='same', activation='relu')(x)
layer_1 = Conv2D(10, (3,3), padding='same', activation='relu')(layer_1)

layer_2 = Conv2D(10, (1,1), padding='same', activation='relu')(x)
layer_2 = Conv2D(10, (5,5), padding='same', activation='relu')(layer_2)

layer_3 = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
layer_3 = Conv2D(10, (1,1), padding='same', activation='relu')(layer_3)

x = keras.layers.concatenate([layer_1, layer_2, layer_3], axis = 3)
# Step 3 - Flattening
flat = Flatten()(x)
# Step 4 - Full connection
output = Dense(units = 64, activation = 'relu')(flat)
output = Dropout(0.3)(output)
output = Dense(units = 2, activation = 'softmax')(output)
# Compiling the CNN
#optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
model = Model([input_img], output)
model.compile(optimizer = 'adadelta', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 122, 122, 3)  444         input_4[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 122, 122, 3)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 61, 61, 3)    0           dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 55, 55, 64)   9472        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 55, 55, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 27, 27, 64)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 21, 21, 128)  401536      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 21, 21, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 10, 10, 128)  0           dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 10)   1290        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 10, 10)   1290        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 10, 10, 128)  0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 10)   910         conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 10, 10, 10)   2510        conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 10, 10, 10)   1290        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 10, 10, 30)   0           conv2d_31[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 3000)         0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           192064      flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            130         dropout_18[0][0]
# ==================================================================================================
# Total params: 610,936
# Trainable params: 610,936
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Data Augmentation

# %%
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)

# %% [markdown]
# ## Training the Model

# %%
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=8),
               steps_per_epoch=200,
               epochs=100,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.69334, saving model to model.h5
# 200/200 - 8s - loss: 0.7112 - accuracy: 0.5206 - val_loss: 0.6933 - val_accuracy: 0.4600
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.69334 to 0.69206, saving model to model.h5
# 200/200 - 8s - loss: 0.7055 - accuracy: 0.5094 - val_loss: 0.6921 - val_accuracy: 0.4850
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.69206 to 0.69186, saving model to model.h5
# 200/200 - 8s - loss: 0.6976 - accuracy: 0.5181 - val_loss: 0.6919 - val_accuracy: 0.4750
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.69186 to 0.69101, saving model to model.h5
# 200/200 - 8s - loss: 0.6968 - accuracy: 0.5144 - val_loss: 0.6910 - val_accuracy: 0.5050
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.69101 to 0.69087, saving model to model.h5
# 200/200 - 8s - loss: 0.7013 - accuracy: 0.5194 - val_loss: 0.6909 - val_accuracy: 0.5050
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.69087 to 0.69028, saving model to model.h5
# 200/200 - 8s - loss: 0.6899 - accuracy: 0.5425 - val_loss: 0.6903 - val_accuracy: 0.5050
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.69028 to 0.69013, saving model to model.h5
# 200/200 - 8s - loss: 0.6880 - accuracy: 0.5462 - val_loss: 0.6901 - val_accuracy: 0.5175
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.69013 to 0.68960, saving model to model.h5
# 200/200 - 8s - loss: 0.6848 - accuracy: 0.5537 - val_loss: 0.6896 - val_accuracy: 0.5325
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.68960 to 0.68941, saving model to model.h5
# 200/200 - 8s - loss: 0.6876 - accuracy: 0.5487 - val_loss: 0.6894 - val_accuracy: 0.5175
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.68941 to 0.68940, saving model to model.h5
# 200/200 - 8s - loss: 0.6769 - accuracy: 0.5700 - val_loss: 0.6894 - val_accuracy: 0.5225
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.68940 to 0.68903, saving model to model.h5
# 200/200 - 8s - loss: 0.6886 - accuracy: 0.5369 - val_loss: 0.6890 - val_accuracy: 0.5000
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.68903 to 0.68859, saving model to model.h5
# 200/200 - 8s - loss: 0.6886 - accuracy: 0.5350 - val_loss: 0.6886 - val_accuracy: 0.5300
# Epoch 13/100
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00013: val_loss improved from 0.68859 to 0.68792, saving model to model.h5
# 200/200 - 8s - loss: 0.6827 - accuracy: 0.5550 - val_loss: 0.6879 - val_accuracy: 0.5250
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.68792 to 0.68754, saving model to model.h5
# 200/200 - 8s - loss: 0.6806 - accuracy: 0.5594 - val_loss: 0.6875 - val_accuracy: 0.5375
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.68754 to 0.68738, saving model to model.h5
# 200/200 - 8s - loss: 0.6770 - accuracy: 0.5800 - val_loss: 0.6874 - val_accuracy: 0.5400
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.68738 to 0.68669, saving model to model.h5
# 200/200 - 8s - loss: 0.6732 - accuracy: 0.5831 - val_loss: 0.6867 - val_accuracy: 0.5275
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.68669
# 200/200 - 8s - loss: 0.6699 - accuracy: 0.5813 - val_loss: 0.6869 - val_accuracy: 0.5200
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.68669 to 0.68620, saving model to model.h5
# 200/200 - 8s - loss: 0.6733 - accuracy: 0.5844 - val_loss: 0.6862 - val_accuracy: 0.5750
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.68620 to 0.68572, saving model to model.h5
# 200/200 - 8s - loss: 0.6806 - accuracy: 0.5625 - val_loss: 0.6857 - val_accuracy: 0.5475
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.68572 to 0.68563, saving model to model.h5
# 200/200 - 8s - loss: 0.6751 - accuracy: 0.5800 - val_loss: 0.6856 - val_accuracy: 0.5225
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.68563 to 0.68400, saving model to model.h5
# 200/200 - 8s - loss: 0.6732 - accuracy: 0.5713 - val_loss: 0.6840 - val_accuracy: 0.5625
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.68400
# 200/200 - 8s - loss: 0.6775 - accuracy: 0.5519 - val_loss: 0.6841 - val_accuracy: 0.5400
# Epoch 23/100
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00023: val_loss did not improve from 0.68400
# 200/200 - 8s - loss: 0.6690 - accuracy: 0.5856 - val_loss: 0.6841 - val_accuracy: 0.5750
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.68400 to 0.68363, saving model to model.h5
# 200/200 - 8s - loss: 0.6688 - accuracy: 0.5856 - val_loss: 0.6836 - val_accuracy: 0.5475
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.68363 to 0.68204, saving model to model.h5
# 200/200 - 8s - loss: 0.6704 - accuracy: 0.5788 - val_loss: 0.6820 - val_accuracy: 0.5850
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.68204
# 200/200 - 8s - loss: 0.6764 - accuracy: 0.5531 - val_loss: 0.6826 - val_accuracy: 0.5650
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.68204
# 200/200 - 8s - loss: 0.6683 - accuracy: 0.5938 - val_loss: 0.6827 - val_accuracy: 0.5475
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.68204 to 0.68193, saving model to model.h5
# 200/200 - 8s - loss: 0.6649 - accuracy: 0.5881 - val_loss: 0.6819 - val_accuracy: 0.5775
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.68193 to 0.68078, saving model to model.h5
# 200/200 - 8s - loss: 0.6645 - accuracy: 0.5919 - val_loss: 0.6808 - val_accuracy: 0.5900
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.68078 to 0.68054, saving model to model.h5
# 200/200 - 8s - loss: 0.6677 - accuracy: 0.5875 - val_loss: 0.6805 - val_accuracy: 0.5925
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.68054
# 200/200 - 8s - loss: 0.6614 - accuracy: 0.5987 - val_loss: 0.6809 - val_accuracy: 0.5650
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.68054 to 0.68026, saving model to model.h5
# 200/200 - 8s - loss: 0.6544 - accuracy: 0.6275 - val_loss: 0.6803 - val_accuracy: 0.5600
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.68026 to 0.67975, saving model to model.h5
# 200/200 - 8s - loss: 0.6611 - accuracy: 0.5981 - val_loss: 0.6798 - val_accuracy: 0.5675
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.67975 to 0.67950, saving model to model.h5
# 200/200 - 8s - loss: 0.6623 - accuracy: 0.6012 - val_loss: 0.6795 - val_accuracy: 0.5650
# Epoch 35/100
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00035: val_loss improved from 0.67950 to 0.67812, saving model to model.h5
# 200/200 - 8s - loss: 0.6650 - accuracy: 0.5894 - val_loss: 0.6781 - val_accuracy: 0.5875
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.67812 to 0.67750, saving model to model.h5
# 200/200 - 8s - loss: 0.6611 - accuracy: 0.5881 - val_loss: 0.6775 - val_accuracy: 0.5950
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.67750 to 0.67718, saving model to model.h5
# 200/200 - 8s - loss: 0.6639 - accuracy: 0.6031 - val_loss: 0.6772 - val_accuracy: 0.5975
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.67718 to 0.67634, saving model to model.h5
# 200/200 - 8s - loss: 0.6564 - accuracy: 0.5987 - val_loss: 0.6763 - val_accuracy: 0.5925
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.67634
# 200/200 - 8s - loss: 0.6573 - accuracy: 0.6075 - val_loss: 0.6765 - val_accuracy: 0.5900
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.67634 to 0.67584, saving model to model.h5
# 200/200 - 8s - loss: 0.6592 - accuracy: 0.6006 - val_loss: 0.6758 - val_accuracy: 0.6225
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.67584
# 200/200 - 8s - loss: 0.6490 - accuracy: 0.6338 - val_loss: 0.6774 - val_accuracy: 0.5725
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.67584 to 0.67472, saving model to model.h5
# 200/200 - 8s - loss: 0.6528 - accuracy: 0.6075 - val_loss: 0.6747 - val_accuracy: 0.6000
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.67472
# 200/200 - 8s - loss: 0.6536 - accuracy: 0.6131 - val_loss: 0.6748 - val_accuracy: 0.6075
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.67472
# 200/200 - 8s - loss: 0.6596 - accuracy: 0.5931 - val_loss: 0.6753 - val_accuracy: 0.5850
# Epoch 45/100
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00045: val_loss did not improve from 0.67472
# 200/200 - 8s - loss: 0.6528 - accuracy: 0.6050 - val_loss: 0.6758 - val_accuracy: 0.5575
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.67472 to 0.67450, saving model to model.h5
# 200/200 - 8s - loss: 0.6497 - accuracy: 0.6231 - val_loss: 0.6745 - val_accuracy: 0.5925
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.67450 to 0.67432, saving model to model.h5
# 200/200 - 8s - loss: 0.6551 - accuracy: 0.5975 - val_loss: 0.6743 - val_accuracy: 0.5950
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.67432 to 0.67312, saving model to model.h5
# 200/200 - 8s - loss: 0.6467 - accuracy: 0.6263 - val_loss: 0.6731 - val_accuracy: 0.5925
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.67312 to 0.67277, saving model to model.h5
# 200/200 - 8s - loss: 0.6487 - accuracy: 0.6181 - val_loss: 0.6728 - val_accuracy: 0.5925
# Epoch 50/100
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00050: val_loss did not improve from 0.67277
# 200/200 - 8s - loss: 0.6534 - accuracy: 0.6119 - val_loss: 0.6731 - val_accuracy: 0.5900
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.67277 to 0.67190, saving model to model.h5
# 200/200 - 8s - loss: 0.6564 - accuracy: 0.6106 - val_loss: 0.6719 - val_accuracy: 0.6375
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.67190
# 200/200 - 8s - loss: 0.6432 - accuracy: 0.6250 - val_loss: 0.6722 - val_accuracy: 0.5975
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.67190
# 200/200 - 8s - loss: 0.6457 - accuracy: 0.6131 - val_loss: 0.6731 - val_accuracy: 0.5675
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.67190 to 0.67076, saving model to model.h5
# 200/200 - 8s - loss: 0.6457 - accuracy: 0.6150 - val_loss: 0.6708 - val_accuracy: 0.6175
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.67076 to 0.66993, saving model to model.h5
# 200/200 - 8s - loss: 0.6458 - accuracy: 0.6263 - val_loss: 0.6699 - val_accuracy: 0.6325
# Epoch 56/100
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00056: val_loss did not improve from 0.66993
# 200/200 - 8s - loss: 0.6364 - accuracy: 0.6525 - val_loss: 0.6700 - val_accuracy: 0.6150
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.66993
# 200/200 - 8s - loss: 0.6488 - accuracy: 0.6288 - val_loss: 0.6709 - val_accuracy: 0.5950
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.66993
# 200/200 - 8s - loss: 0.6490 - accuracy: 0.6225 - val_loss: 0.6703 - val_accuracy: 0.6025
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.66993
# 200/200 - 8s - loss: 0.6437 - accuracy: 0.6250 - val_loss: 0.6707 - val_accuracy: 0.5925
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.66993 to 0.66869, saving model to model.h5
# 200/200 - 8s - loss: 0.6403 - accuracy: 0.6331 - val_loss: 0.6687 - val_accuracy: 0.6550
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.66869
# 200/200 - 8s - loss: 0.6470 - accuracy: 0.6444 - val_loss: 0.6700 - val_accuracy: 0.6025
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.66869
# 200/200 - 8s - loss: 0.6410 - accuracy: 0.6244 - val_loss: 0.6694 - val_accuracy: 0.6050
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.66869 to 0.66794, saving model to model.h5
# 200/200 - 8s - loss: 0.6467 - accuracy: 0.6125 - val_loss: 0.6679 - val_accuracy: 0.6100
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.66794
# 200/200 - 8s - loss: 0.6515 - accuracy: 0.6194 - val_loss: 0.6684 - val_accuracy: 0.6050
# Epoch 65/100
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00065: val_loss did not improve from 0.66794
# 200/200 - 8s - loss: 0.6400 - accuracy: 0.6275 - val_loss: 0.6683 - val_accuracy: 0.6025
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.66794
# 200/200 - 8s - loss: 0.6429 - accuracy: 0.6194 - val_loss: 0.6681 - val_accuracy: 0.6125
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.66794
# 200/200 - 8s - loss: 0.6486 - accuracy: 0.6119 - val_loss: 0.6705 - val_accuracy: 0.5725
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.66794
# 200/200 - 8s - loss: 0.6456 - accuracy: 0.6169 - val_loss: 0.6685 - val_accuracy: 0.6050
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.66794 to 0.66663, saving model to model.h5
# 200/200 - 8s - loss: 0.6356 - accuracy: 0.6263 - val_loss: 0.6666 - val_accuracy: 0.6575
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.66663
# 200/200 - 8s - loss: 0.6406 - accuracy: 0.6306 - val_loss: 0.6675 - val_accuracy: 0.6075
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 0.66663 to 0.66636, saving model to model.h5
# 200/200 - 8s - loss: 0.6421 - accuracy: 0.6250 - val_loss: 0.6664 - val_accuracy: 0.6150
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.66636
# 200/200 - 8s - loss: 0.6487 - accuracy: 0.6150 - val_loss: 0.6679 - val_accuracy: 0.6075
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.66636
# 200/200 - 8s - loss: 0.6397 - accuracy: 0.6237 - val_loss: 0.6671 - val_accuracy: 0.6050
# Epoch 74/100
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00074: val_loss improved from 0.66636 to 0.66578, saving model to model.h5
# 200/200 - 8s - loss: 0.6379 - accuracy: 0.6175 - val_loss: 0.6658 - val_accuracy: 0.6575
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.66578 to 0.66520, saving model to model.h5
# 200/200 - 8s - loss: 0.6350 - accuracy: 0.6419 - val_loss: 0.6652 - val_accuracy: 0.6525
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.66520
# 200/200 - 8s - loss: 0.6377 - accuracy: 0.6331 - val_loss: 0.6662 - val_accuracy: 0.6100
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.66520
# 200/200 - 8s - loss: 0.6405 - accuracy: 0.6175 - val_loss: 0.6665 - val_accuracy: 0.6125
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.66520 to 0.66515, saving model to model.h5
# 200/200 - 8s - loss: 0.6324 - accuracy: 0.6331 - val_loss: 0.6651 - val_accuracy: 0.6100
# Epoch 79/100
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00079: val_loss improved from 0.66515 to 0.66429, saving model to model.h5
# 200/200 - 8s - loss: 0.6407 - accuracy: 0.6200 - val_loss: 0.6643 - val_accuracy: 0.6425
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.66429
# 200/200 - 8s - loss: 0.6409 - accuracy: 0.6400 - val_loss: 0.6662 - val_accuracy: 0.6025
# Epoch 81/100
#
# Epoch 00081: val_loss improved from 0.66429 to 0.66359, saving model to model.h5
# 200/200 - 8s - loss: 0.6351 - accuracy: 0.6388 - val_loss: 0.6636 - val_accuracy: 0.6650
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.66359
# 200/200 - 8s - loss: 0.6436 - accuracy: 0.6300 - val_loss: 0.6640 - val_accuracy: 0.6250
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.66359
# 200/200 - 8s - loss: 0.6378 - accuracy: 0.6250 - val_loss: 0.6649 - val_accuracy: 0.6150
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.66359
# 200/200 - 8s - loss: 0.6382 - accuracy: 0.6281 - val_loss: 0.6651 - val_accuracy: 0.6025
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.66359
# 200/200 - 8s - loss: 0.6398 - accuracy: 0.6344 - val_loss: 0.6658 - val_accuracy: 0.5925
# Epoch 86/100
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00086: val_loss did not improve from 0.66359
# 200/200 - 8s - loss: 0.6385 - accuracy: 0.6275 - val_loss: 0.6642 - val_accuracy: 0.6150
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.66359 to 0.66321, saving model to model.h5
# 200/200 - 8s - loss: 0.6348 - accuracy: 0.6356 - val_loss: 0.6632 - val_accuracy: 0.6500
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.66321
# 200/200 - 8s - loss: 0.6318 - accuracy: 0.6463 - val_loss: 0.6640 - val_accuracy: 0.6125
# Epoch 89/100
#
# Epoch 00089: val_loss improved from 0.66321 to 0.66278, saving model to model.h5
# 200/200 - 8s - loss: 0.6363 - accuracy: 0.6381 - val_loss: 0.6628 - val_accuracy: 0.6375
# Epoch 90/100
#
# Epoch 00090: val_loss improved from 0.66278 to 0.66153, saving model to model.h5
# 200/200 - 8s - loss: 0.6375 - accuracy: 0.6300 - val_loss: 0.6615 - val_accuracy: 0.6625
# Epoch 91/100
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00091: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6346 - accuracy: 0.6331 - val_loss: 0.6631 - val_accuracy: 0.6150
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6382 - accuracy: 0.6338 - val_loss: 0.6630 - val_accuracy: 0.6150
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6391 - accuracy: 0.6369 - val_loss: 0.6622 - val_accuracy: 0.6575
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6401 - accuracy: 0.6356 - val_loss: 0.6626 - val_accuracy: 0.6175
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6337 - accuracy: 0.6344 - val_loss: 0.6618 - val_accuracy: 0.6225
# Epoch 96/100
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00096: val_loss did not improve from 0.66153
# 200/200 - 8s - loss: 0.6356 - accuracy: 0.6250 - val_loss: 0.6619 - val_accuracy: 0.6200
# Epoch 97/100
#
# Epoch 00097: val_loss improved from 0.66153 to 0.66119, saving model to model.h5
# 200/200 - 8s - loss: 0.6371 - accuracy: 0.6237 - val_loss: 0.6612 - val_accuracy: 0.6450
# Epoch 98/100
#
# Epoch 00098: val_loss improved from 0.66119 to 0.66022, saving model to model.h5
# 200/200 - 8s - loss: 0.6358 - accuracy: 0.6406 - val_loss: 0.6602 - val_accuracy: 0.6650
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.66022
# 200/200 - 8s - loss: 0.6280 - accuracy: 0.6394 - val_loss: 0.6611 - val_accuracy: 0.6525
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.66022
# 200/200 - 8s - loss: 0.6352 - accuracy: 0.6313 - val_loss: 0.6617 - val_accuracy: 0.6275

# %% [markdown]
# ##Plotting Acc and Loss Plots

# %%
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label = 'train')
plt.plot(history.history['val_accuracy'], label = 'test')
plt.title('accuracy')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.title('Loss')
plt.legend()
plt.subplots_adjust(right = 1.5)
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

Y_pred = classifier.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
result = classifier.predict(X_val)
r = abs(np.round(result)-Y_val).sum()
(400-r)/400
# Out:
# 0.87

# %%
result = classifier.predict(X_train)
r = abs(np.round(result)-Y_train).sum()
(1600-r)/1600
# Out:
# 0.88

# %% [markdown]
# ## Saving Model

# %%
# !mkdir -p saved_model
classifier.save('saved_model/my_model')

# %%
# !ls saved_model/my_model
# Out:
# saved_model/my_model

# %%
import tensorflow as tf
from tensorflow import keras
new_model = tf.keras.models.load_model('saved_model/my_model')

# Check its architecture
new_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 122, 122, 32)      4736
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 122, 122, 32)      0
# _________________________________________________________________
# activation_3 (Activation)    (None, 122, 122, 32)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 61, 61, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 55, 55, 64)        100416
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 55, 55, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 21, 21, 128)       401536
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 21, 21, 128)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                819264
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,326,082
# Trainable params: 1,326,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = new_model.predict(X_val)
r = abs(np.round(result)-Y_val).sum()
(400-r)/400
# Out:
# 0.87

# %% [markdown]
# ## Saving Model with pythorch

# %%
import torch
from torchvision import datasets, models, transforms

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
model_save_name = 'COVID19.h5'
#path = F"/content/gdrive/My Drive/{model_save_name}" 
#torch.save(classifier, path)
classifier.save('/content/gdrive/My Drive/COVID19.h5')
