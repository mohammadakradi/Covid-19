# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammad2682/Covid-19/blob/master/Covid_19_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
if not os.path.isdir("images"):
  # !git clone https://github.com/mohammad2682/covid-chestxray-dataset
  # !ls
# Out:
# fatal: destination path 'covid-chestxray-dataset' already exists and is not an empty directory.
# covid-chestxray-dataset  sample_data

# %%
I1 = cv2.imread('covid-chestxray-dataset/images/1-s2.0-S0140673620303706-fx1_lrg.jpg',0)
print(type(I1))
plt.imshow(I1, cmap='gray')
# Out:
# mv: missing destination file operand after 'covid-chestxray-dataset/images'
# Try 'mv --help' for more information.
# <class 'numpy.ndarray'>
